# %%
import os
contenido = os.listdir('train2017/train2017')
contenido[:5]
# Out:
# ['000000067792.jpg',
#  '000000575428.jpg',
#  '000000208107.jpg',
#  '000000278222.jpg',
#  '000000086064.jpg']

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
image = mpimg.imread("train2017/train2017/000000067792.jpg")
plt.imshow(image)
plt.show()
